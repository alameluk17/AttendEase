# %%
from pymoodle import MoodleWebServiceAPIClient
jsonobj = {"moken":"46ce70716e5f6449be34650727713352"}
moodle = MoodleWebServiceAPIClient(token=jsonobj["moken"],api_base="https://lms.ssn.edu.in")
moodle.get_user_courses(userid=moodle.CLIENT_USER_DATA["userid"])
# Out:
# [{'id': 386,
#   'shortname': 'UCS2313-OOPLab-CSE-A-22',
#   'fullname': 'UCS2313 --- Object Oriented Programming Lab --- CSE --- Section A --- 2022 Edition',
#   'displayname': 'UCS2313 --- Object Oriented Programming Lab --- CSE --- Section A --- 2022 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 22,
#   'progress': 50,
#   'completed': False,
#   'startdate': 1664562600,
#   'enddate': 1695925800,
#   'marker': 0,
#   'lastaccess': 1688885301,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1687749767},
#  {'id': 384,
#   'shortname': 'UCS2312-DSLab-CSE-A-22',
#   'fullname': 'UCS2312 --- Data Structures Lab --- CSE --- Section A --- 2022 Edition',
#   'displayname': 'UCS2312 --- Data Structures Lab --- CSE --- Section A --- 2022 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 22,
#   'progress': 70,
#   'completed': False,
#   'startdate': 1664562600,
#   'enddate': 1680028200,
#   'marker': 0,
#   'lastaccess': 1676224022,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1664509285},
#  {'id': 382,
#   'shortname': 'UCS2311-DDLab-CSE-A-22',
#   'fullname': 'UCS2311 --- Digital Design Lab --- CSE --- Section A --- 2022 Edition',
#   'displayname': 'UCS2311 --- Digital Design Lab --- CSE --- Section A --- 2022 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 22,
#   'progress': 0,
#   'completed': False,
#   'startdate': 1664562600,
#   'enddate': 1680028200,
#   'marker': 0,
#   'lastaccess': 1675947266,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1664509140},
#  {'id': 380,
#   'shortname': 'UCS2303-OOP-CSE-A-22',
#   'fullname': 'UCS2303 --- Object Oriented Programming --- CSE --- Section A --- 2022 Edition',
#   'displayname': 'UCS2303 --- Object Oriented Programming --- CSE --- Section A --- 2022 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 22,
#   'progress': 8.47457627118644,
#   'completed': False,
#   'startdate': 1664562600,
#   'enddate': 1680028200,
#   'marker': 0,
#   'lastaccess': 1676603472,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1664508958},
#  {'id': 378,
#   'shortname': 'UCS2302-DS- CSE-A-22 ',
#   'fullname': 'UCS2302 --- Data Structures --- CSE --- Section A --- 2022 Edition',
#   'displayname': 'UCS2302 --- Data Structures --- CSE --- Section A --- 2022 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 22,
#   'progress': 13.793103448275861,
#   'completed': False,
#   'startdate': 1664562600,
#   'enddate': 1680028200,
#   'marker': 0,
#   'lastaccess': 1694767780,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1664508605},
#  {'id': 376,
#   'shortname': 'UCS2301-DPSD-CSE-A-22',
#   'fullname': 'UCS2301--- Digital Principles and System Design --- CSE --- Section A --- 2022 Edition',
#   'displayname': 'UCS2301--- Digital Principles and System Design --- CSE --- Section A --- 2022 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 22,
#   'progress': 3.9215686274509802,
#   'completed': False,
#   'startdate': 1664562600,
#   'enddate': 1680028200,
#   'marker': 0,
#   'lastaccess': 1675985586,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1664508434},
#  {'id': 374,
#   'shortname': 'UHS2351-UHVII-CSE-A-22',
#   'fullname': 'UHS2351--- Universal Human Values II --- CSE --- Section A --- 2022 Edition',
#   'displayname': 'UHS2351--- Universal Human Values II --- CSE --- Section A --- 2022 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 22,
#   'progress': 13.793103448275861,
#   'completed': False,
#   'startdate': 1664562600,
#   'enddate': 1680028200,
#   'marker': 0,
#   'lastaccess': 1676901250,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1664508232},
#  {'id': 370,
#   'shortname': 'PEOs, POS and PSOs',
#   'fullname': 'PEOs, POs and PSOs',
#   'displayname': 'PEOs, POs and PSOs',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 22,
#   'progress': 0,
#   'completed': False,
#   'startdate': 1663785000,
#   'enddate': 1705689000,
#   'marker': 0,
#   'lastaccess': None,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1663852310},
#  {'id': 341,
#   'shortname': 'CSE CAT',
#   'fullname': 'CSE-CAT',
#   'displayname': 'CSE-CAT',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 22,
#   'progress': 3.614457831325301,
#   'completed': False,
#   'startdate': 1663093800,
#   'enddate': 1705084200,
#   'marker': 0,
#   'lastaccess': 1672060772,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1663126593},
#  {'id': 1044,
#   'shortname': 'AHS2476-IC-CSE-A',
#   'fullname': 'AHS2476---Indian Constitution---CSE---Section A--- 2023 Edition ',
#   'displayname': 'AHS2476---Indian Constitution---CSE---Section A--- 2023 Edition ',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 44,
#   'progress': 11.11111111111111,
#   'completed': False,
#   'startdate': 1677004200,
#   'enddate': 1695148200,
#   'marker': 0,
#   'lastaccess': 1687684354,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1686798847},
#  {'id': 952,
#   'shortname': 'UCS2411-Db Lab-CSE-A-23',
#   'fullname': 'UCS2411---Database Lab---CSE---Section A---2023 Edition ',
#   'displayname': 'UCS2411---Database Lab---CSE---Section A---2023 Edition ',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 44,
#   'progress': 70.58823529411765,
#   'completed': False,
#   'startdate': 1677609000,
#   'enddate': 1690569000,
#   'marker': 0,
#   'lastaccess': 1716444707,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1677575120},
#  {'id': 950,
#   'shortname': 'UCS2412-OS Lab-CSE-A-23',
#   'fullname': 'UCS2412---Operating Systems Lab---CSE---Section A---2023 Edition ',
#   'displayname': 'UCS2412---Operating Systems Lab---CSE---Section A---2023 Edition ',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 44,
#   'progress': 53.84615384615385,
#   'completed': False,
#   'startdate': 1677609000,
#   'enddate': 1690569000,
#   'marker': 0,
#   'lastaccess': 1688885309,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1677574918},
#  {'id': 948,
#   'shortname': 'UCS2404-DBMS-CSE-A-23',
#   'fullname': 'UCS2404---Database Management Systems---CSE---Section A---2023 Edition',
#   'displayname': 'UCS2404---Database Management Systems---CSE---Section A---2023 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 44,
#   'progress': 6.521739130434782,
#   'completed': False,
#   'startdate': 1677609000,
#   'enddate': 1690569000,
#   'marker': 0,
#   'lastaccess': 1718393421,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1677574755},
#  {'id': 946,
#   'shortname': 'UCS2403-DAA-CSE-A-23',
#   'fullname': 'UCS2403---Design and Analysis of Algorithms (TCP)---CSE---Section A---2023 Edition',
#   'displayname': 'UCS2403---Design and Analysis of Algorithms (TCP)---CSE---Section A---2023 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 44,
#   'progress': 39.130434782608695,
#   'completed': False,
#   'startdate': 1677609000,
#   'enddate': 1690569000,
#   'marker': 0,
#   'lastaccess': 1689707657,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1677574405},
#  {'id': 944,
#   'shortname': 'UCS2402-OS-CSE-A-23',
#   'fullname': 'UCS2402---Operating Systems---CSE---Section A---2023 Edition ',
#   'displayname': 'UCS2402---Operating Systems---CSE---Section A---2023 Edition ',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 44,
#   'progress': 7.894736842105263,
#   'completed': False,
#   'startdate': 1677609000,
#   'enddate': 1690569000,
#   'marker': 0,
#   'lastaccess': 1689306363,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1677574239},
#  {'id': 942,
#   'shortname': 'UCS2401-COA-CSE-A-23',
#   'fullname': 'UCS2401---Computer Organization and Architecture---CSE---Section A---2023 Edition',
#   'displayname': 'UCS2401---Computer Organization and Architecture---CSE---Section A---2023 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 44,
#   'progress': 9.090909090909092,
#   'completed': False,
#   'startdate': 1677609000,
#   'enddate': 1722191400,
#   'marker': 0,
#   'lastaccess': 1689089287,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1717040147},
#  {'id': 2024,
#   'shortname': 'UBA2541-POM-CSE-A-23',
#   'fullname': 'UBA2541---Principles of Management---CSE---Section A ---2023 Edition',
#   'displayname': 'UBA2541---Principles of Management---CSE---Section A ---2023 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 59,
#   'progress': None,
#   'completed': False,
#   'startdate': 1693074600,
#   'enddate': 1713897000,
#   'marker': 0,
#   'lastaccess': None,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1698295027},
#  {'id': 1497,
#   'shortname': 'ucs2523-ipa-cse-a&amp;b-23',
#   'fullname': 'UCS2523--- Image Processing and Analysis (Elective)--- CSE---Section A &amp; B---2023 Edition',
#   'displayname': 'UCS2523--- Image Processing and Analysis (Elective)--- CSE---Section A &amp; B---2023 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 59,
#   'progress': 25.71428571428571,
#   'completed': False,
#   'startdate': 1691173800,
#   'enddate': 1703961000,
#   'marker': 0,
#   'lastaccess': 1703089044,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1691136462},
#  {'id': 1488,
#   'shortname': 'ucs2512-mplab-cse-a-23',
#   'fullname': 'UCS2512--- Microprocessors Lab--- Section A---2023 Edition',
#   'displayname': 'UCS2512--- Microprocessors Lab--- Section A---2023 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 59,
#   'progress': 75,
#   'completed': False,
#   'startdate': 1691173800,
#   'enddate': 1703961000,
#   'marker': 0,
#   'lastaccess': 1701196271,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1693363090},
#  {'id': 1487,
#   'shortname': 'ucs2511-nl-cse-a-23',
#   'fullname': 'UCS2511--- Networks Lab--- Section A---2023 Edition',
#   'displayname': 'UCS2511--- Networks Lab--- Section A---2023 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 59,
#   'progress': 30.76923076923077,
#   'completed': False,
#   'startdate': 1691173800,
#   'enddate': 1703961000,
#   'marker': 0,
#   'lastaccess': 1704775424,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1691134399},
#  {'id': 1481,
#   'shortname': 'ucs2504-fai-cse-a-23',
#   'fullname': 'UCS2504--- Foundations of Artificial Intelligence (TCP) --- Section A---2023 Edition',
#   'displayname': 'UCS2504--- Foundations of Artificial Intelligence (TCP) --- Section A---2023 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 59,
#   'progress': 68.08510638297872,
#   'completed': False,
#   'startdate': 1691173800,
#   'enddate': 1703961000,
#   'marker': 0,
#   'lastaccess': 1704164386,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1691133776},
#  {'id': 1479,
#   'shortname': 'ucs2502-mpi-cse-a-23',
#   'fullname': 'UCS2502--- Microprocessors, Microcontrollers  and  Interfacing--- Section A---2023 Edition',
#   'displayname': 'UCS2502--- Microprocessors, Microcontrollers  and  Interfacing--- Section A---2023 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 59,
#   'progress': 57.377049180327866,
#   'completed': False,
#   'startdate': 1691173800,
#   'enddate': 1703961000,
#   'marker': 0,
#   'lastaccess': 1713755381,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1691133540},
#  {'id': 1476,
#   'shortname': 'ucs2501-cn-cse-a-23 ',
#   'fullname': 'UCS2501--- Computer Networks--- CSE---Section A---2023 Edition',
#   'displayname': 'UCS2501--- Computer Networks--- CSE---Section A---2023 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 59,
#   'progress': 2.564102564102564,
#   'completed': False,
#   'startdate': 1691346600,
#   'enddate': 1701369000,
#   'marker': 0,
#   'lastaccess': 1705025270,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1691132691},
#  {'id': 2240,
#   'shortname': 'UCS2612-ML Lab- CSE-A-24',
#   'fullname': 'UCS2612--- Machine Learning Lab ---CSE---Section A ---2024 Edition',
#   'displayname': 'UCS2612--- Machine Learning Lab ---CSE---Section A ---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 91,
#   'progress': 59.25925925925925,
#   'completed': False,
#   'startdate': 1706553000,
#   'enddate': 1722191400,
#   'marker': 0,
#   'lastaccess': 1717952176,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1706498967},
#  {'id': 2238,
#   'shortname': 'UCS2611-IP Lab- CSE-A-24',
#   'fullname': 'UCS2611--- Internet Programming Lab ---CSE---Section A ---2024 Edition',
#   'displayname': 'UCS2611--- Internet Programming Lab ---CSE---Section A ---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 91,
#   'progress': 77.77777777777779,
#   'completed': False,
#   'startdate': 1706553000,
#   'enddate': 1722191400,
#   'marker': 0,
#   'lastaccess': 1716400912,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1706498769},
#  {'id': 2235,
#   'shortname': 'UCS2626-NLP- CSE-A-24',
#   'fullname': 'UCS2626--- Natural Language Processing and Applications ---CSE---Section A---2024 Edition',
#   'displayname': 'UCS2626--- Natural Language Processing and Applications ---CSE---Section A---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 91,
#   'progress': 37.254901960784316,
#   'completed': False,
#   'startdate': 1706553000,
#   'enddate': 1722191400,
#   'marker': 0,
#   'lastaccess': 1718123701,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1706498570},
#  {'id': 2233,
#   'shortname': 'UCS2603-TOC- CSE-A-24',
#   'fullname': 'UCS2603--- Theory of Computation ---CSE---Section A---2024 Edition',
#   'displayname': 'UCS2603--- Theory of Computation ---CSE---Section A---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 91,
#   'progress': 6.451612903225806,
#   'completed': False,
#   'startdate': 1706553000,
#   'enddate': 1722191400,
#   'marker': 0,
#   'lastaccess': 1716623097,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1706497639},
#  {'id': 2231,
#   'shortname': 'UCS2604-PML- CSE-A-24',
#   'fullname': 'UCS2604--- Principles of Machine Learning---CSE---Section A---2024 Edition',
#   'displayname': 'UCS2604--- Principles of Machine Learning---CSE---Section A---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 91,
#   'progress': 2.3529411764705883,
#   'completed': False,
#   'startdate': 1706553000,
#   'enddate': 1722191400,
#   'marker': 0,
#   'lastaccess': 1717952291,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1706497470},
#  {'id': 2229,
#   'shortname': 'UCS2602-SSS- CSE-A-24',
#   'fullname': 'UCS2602--- Software System Security---CSE---Section A---2024 Edition',
#   'displayname': 'UCS2602--- Software System Security---CSE---Section A---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 91,
#   'progress': 0,
#   'completed': False,
#   'startdate': 1706553000,
#   'enddate': 1722191400,
#   'marker': 0,
#   'lastaccess': 1717526174,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1706496996},
#  {'id': 2227,
#   'shortname': 'UCS2601-IP-CSE-A-24',
#   'fullname': 'UCS2601--- Internet Programming---CSE---Section A---2024 Edition',
#   'displayname': 'UCS2601--- Internet Programming---CSE---Section A---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 91,
#   'progress': 10,
#   'completed': False,
#   'startdate': 1706553000,
#   'enddate': 1722191400,
#   'marker': 0,
#   'lastaccess': 1726294257,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1706496812},
#  {'id': 3136,
#   'shortname': 'CSA',
#   'fullname': "CSE STUDENT'S ACTIVITIES 2024 - 25",
#   'displayname': "CSE STUDENT'S ACTIVITIES 2024 - 25",
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 109,
#   'progress': 0,
#   'completed': False,
#   'startdate': 1722796200,
#   'enddate': 1733164200,
#   'marker': 0,
#   'lastaccess': 1724125338,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1722749166},
#  {'id': 2912,
#   'shortname': 'UCS2717-PW PI-24',
#   'fullname': 'UCS2717---Project Work Phase I ---CSE---Section A,B,C ---2024 Edition',
#   'displayname': 'UCS2717---Project Work Phase I ---CSE---Section A,B,C ---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 109,
#   'progress': 0,
#   'completed': False,
#   'startdate': 1722105000,
#   'enddate': 1735065000,
#   'marker': 0,
#   'lastaccess': None,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1722048878},
#  {'id': 2834,
#   'shortname': 'UCS2716-Train-Inter-2024',
#   'fullname': 'UCS2716---Industrial Training / Internhip---CSE---Section A,B ---2024 Edition',
#   'displayname': 'UCS2716---Industrial Training / Internhip---CSE---Section A,B ---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 109,
#   'progress': 100,
#   'completed': False,
#   'startdate': 1722018600,
#   'enddate': 1734978600,
#   'marker': 0,
#   'lastaccess': 1726294781,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1721975530},
#  {'id': 2833,
#   'shortname': 'UCS2735-BIT-2024',
#   'fullname': 'UCS2735---Bioinformatics Technologies (PE V) ---CSE---Section A,B ---2024 Edition',
#   'displayname': 'UCS2735---Bioinformatics Technologies (PE V) ---CSE---Section A,B ---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 109,
#   'progress': 0,
#   'completed': False,
#   'startdate': 1722018600,
#   'enddate': 1734978600,
#   'marker': 0,
#   'lastaccess': 1727627944,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1721975477},
#  {'id': 2830,
#   'shortname': 'UCS2727-UED-2024',
#   'fullname': 'UCS2727---User Experience Design (PEIV) ---CSE---Section A,B ---2024 Edition',
#   'displayname': 'UCS2727---User Experience Design (PEIV) ---CSE---Section A,B ---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 109,
#   'progress': 14.285714285714285,
#   'completed': False,
#   'startdate': 1722018600,
#   'enddate': 1734978600,
#   'marker': 0,
#   'lastaccess': 1728891906,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1721975311},
#  {'id': 2828,
#   'shortname': 'UCS2722-OOAD-2024',
#   'fullname': 'UCS2722---Object Oriented Analysis and Design (PEIII) ---CSE---Section A,B ---2024 Edition',
#   'displayname': 'UCS2722---Object Oriented Analysis and Design (PEIII) ---CSE---Section A,B ---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 109,
#   'progress': 5.555555555555555,
#   'completed': False,
#   'startdate': 1722018600,
#   'enddate': 1734978600,
#   'marker': 0,
#   'lastaccess': 1729712489,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1721975186},
#  {'id': 2824,
#   'shortname': 'UCS2702-CD-A-2024',
#   'fullname': 'UCS2702---Compiler Design(TCP) ---CSE---Section A ---2024 Edition',
#   'displayname': 'UCS2702---Compiler Design(TCP) ---CSE---Section A ---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 109,
#   'progress': 8.47457627118644,
#   'completed': False,
#   'startdate': 1722018600,
#   'enddate': 1734978600,
#   'marker': 0,
#   'lastaccess': 1729659421,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1721974770},
#  {'id': 2823,
#   'shortname': 'UCS2703-SA-A-2024',
#   'fullname': 'UCS2703---Software Architecture---CSE---Section A ---2024 Edition',
#   'displayname': 'UCS2703---Software Architecture---CSE---Section A ---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 109,
#   'progress': 4,
#   'completed': False,
#   'startdate': 1722018600,
#   'enddate': 1734978600,
#   'marker': 0,
#   'lastaccess': 1729616847,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1721974602},
#  {'id': 2822,
#   'shortname': 'UCS2701-DS-A-2024',
#   'fullname': 'UCS2701---Distributed Systems---CSE---Section A ---2024 Edition',
#   'displayname': 'UCS2701---Distributed Systems---CSE---Section A ---2024 Edition',
#   'idnumber': '',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 109,
#   'progress': 0,
#   'completed': False,
#   'startdate': 1722018600,
#   'enddate': 1734978600,
#   'marker': 0,
#   'lastaccess': 1729441925,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1721974546},
#  {'id': 351,
#   'shortname': 'uma2377-dm-csea-2022',
#   'fullname': 'UMA2377---Discrete Mathematics---CSE---SECTION A---2022 Edition\t',
#   'displayname': 'UMA2377---Discrete Mathematics---CSE---SECTION A---2022 Edition\t',
#   'idnumber': 'uma2377-dm-csea-2022',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 28,
#   'progress': 5.263157894736842,
#   'completed': False,
#   'startdate': 1664220600,
#   'enddate': 1677612600,
#   'marker': 0,
#   'lastaccess': 1675824087,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1664252072},
#  {'id': 916,
#   'shortname': 'uma2476-ps-csea-23',
#   'fullname': 'UMA2476---Probability and Statistics---CSE---SECTION A---2023 Edition\t',
#   'displayname': 'UMA2476---Probability and Statistics---CSE---SECTION A---2023 Edition\t',
#   'idnumber': 'uma2476-ps-csea-23',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 48,
#   'progress': 5.714285714285714,
#   'completed': False,
#   'startdate': 1677522600,
#   'enddate': 1687890600,
#   'marker': 0,
#   'lastaccess': 1688899156,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1677558798},
#  {'id': 2317,
#   'shortname': 'uma2042-Ila-oe1-24',
#   'fullname': 'UMA2042--- Introduction to Linear Algebra---VI (OE)--- SECTION 1---2024 Edition',
#   'displayname': 'UMA2042--- Introduction to Linear Algebra---VI (OE)--- SECTION 1---2024 Edition',
#   'idnumber': 'uma2042-Ila-oe1-24',
#   'visible': 1,
#   'summary': '',
#   'summaryformat': 1,
#   'format': 'topics',
#   'showgrades': True,
#   'lang': '',
#   'enablecompletion': True,
#   'completionhascriteria': False,
#   'completionusertracked': True,
#   'category': 95,
#   'progress': 13.88888888888889,
#   'completed': False,
#   'startdate': 1704047400,
#   'enddate': 1722281400,
#   'marker': 0,
#   'lastaccess': 1718300216,
#   'isfavourite': False,
#   'hidden': False,
#   'overviewfiles': [],
#   'showactivitydates': True,
#   'showcompletionconditions': True,
#   'timemodified': 1707202933}]
